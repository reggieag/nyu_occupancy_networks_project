# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
#The Encoder network for single view 3D reconstruction is a ResNet18 pretrained
#on the ImageNet dataset with the last fully-connected layer adjusted to project
#the features to a 256 dimensional embedding, "c"
from torchvision.models.resnet import resnet18 as _resnet18
import numpy
from PIL import Image
import io

# %%
K = 10
batch_size = 20
device = 'cuda'

# %%
class Block(nn.Module):
    def __init__(self):
        super(Block,self).__init__()
        self.fc1 = nn.Conv1d(256,256,kernel_size=1)
        self.fc2 = nn.Conv1d(256,256,kernel_size=1)
        self.bn1 = nn.BatchNorm1d(256, affine=False, track_running_stats=True)
        self.bn2 = nn.BatchNorm1d(256, affine=False, track_running_stats=True)
        self.gammaLayer1 = nn.Conv1d(256,256,kernel_size=1)
        self.gammaLayer2 = nn.Conv1d(256,256,kernel_size=1)
        self.betaLayer1 = nn.Conv1d(256,256,kernel_size=1)
        self.betaLayer2 = nn.Conv1d(256,256,kernel_size=1)
        
    def forward(self,y):
        x = y['ex']
        encoding = y['enc']
        gamma = self.gammaLayer1(encoding)
        beta = self.betaLayer1(encoding)
        #First apply Conditional Batch Normalization
        out = gamma*self.bn1(x) + beta
        #Then ReLU activation function
        out = F.relu(out)
        #fully connected layer
        out = self.fc1(out)
        #Second CBN layer
        gamma = self.gammaLayer2(encoding)
        beta = self.betaLayer2(encoding)
        out = gamma*self.bn2(out) + beta
        #RELU activation
        out = F.relu(out)
        #2nd fully connected
        out = self.fc2(out)
        #Add to the input of the ResNet Block 
        out = x + out
        
        return {'ex':out, 'enc':encoding}

# %%
class OccupancyModel(nn.Module):
    def __init__(self):
        super(OccupancyModel,self).__init__()
        self.blocks = self.makeBlocks()
        self.encoderModel = _resnet18(pretrained=True)
        self.fc_enc = nn.Linear(1000, 256)
        self.gammaLayer = nn.Conv1d(256,256,kernel_size=1)
        self.betaLayer = nn.Conv1d(256,256,kernel_size=1)
        self.cbn = nn.BatchNorm1d(256, affine=False, track_running_stats=True)
        self.fc1 = nn.Conv1d(3,256,kernel_size=1)
        self.fc2 = nn.Conv1d(256,1,kernel_size=1)
        
    def makeBlocks(self):
        blocks = []
        for _ in range(5):
            blocks.append(Block())
        return nn.Sequential(*blocks)
   
  
    def forward(self,x,img):
        img = self.encoderModel(img)
        img = self.fc_enc(img)
        img = img.view(-1,256,1)
        x = self.fc1(x)
        #5 pre-activation ResNet-blocks
        x = self.blocks({'enc':img , 'ex':x })
        x = x['ex']
        #CBN
        gamma = self.gammaLayer(img)
        beta = self.betaLayer(img)
        x = gamma*self.cbn(x) + beta
        x = F.relu(x)
        x = self.fc2(x)
        x = x.view(-1,1)
        x = torch.sigmoid(x)
        return x

# %%
modelTest = OccupancyModel()
#Input to the occupancy network architecture is the 
#output of the encoder network and a batch of 3D coordinates. 
coords = torch.rand(20,3,1)
image = torch.rand(20,3,137,137)
modelTest.eval()

p = modelTest(coords,image)

# %%
#The following is evidence that the fc layers in the encoder are indeed updating their weights 
modelCriterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr = 0.001)
model.train()

# %%
output = model(coords,image)
print(f"out: {output}")
loss = modelCriterion(output, torch.rand(output.size()))
print(f"loss: {loss}")
loss.backward()
optimizer.step()

# %%
#load some data:
#The .npz contains "points, occupancies, loc, scale" 
with numpy.load("/home/andrea/Documents/GradSchool/OccupancyNetworks/occupancy_networks/data/ShapeNet/02691156/fd528602cbde6f11bbf3143b1cb6076a/points.npz") as data:
    pts = torch.tensor(data["points"], dtype=torch.float)
    occupancies = torch.tensor(numpy.unpackbits(data["occupancies"])[:pts.size()[0]], dtype=torch.float)

image = numpy.array(Image.open("/home/andrea/Documents/GradSchool/OccupancyNetworks/occupancy_networks/data/ShapeNet/02691156/fd528602cbde6f11bbf3143b1cb6076a/img_choy2016/015.jpg"))
#At least for this image directory, the jpgs come in as 137,137,3
image = torch.tensor(image,dtype=torch.float).permute(2,0,1)
image = image.view(1,3,137,137)

train_loader = torch.utils.data.DataLoader(list(zip(pts,occupancies)), batch_size=batch_size)

# %%
def train(epoch, model, trainloader, optimizer):
    modelCriterion = nn.BCELoss()
    model.train()
    for batch_idx, data in enumerate(train_loader):
        (images, pts, occupancies) = data
        #Each batch size contains batch_size sets of "K" points
        #Collapse those two dimensions
        images = images.view(batch_size*K,3,137,137).cuda() #make robust
        pts = pts.view(batch_size*K, 3,1).cuda()
        occupancies = occupancies.view(batch_size*K,1).cuda()
        optimizer.zero_grad()
        output = model(pts, images) #a probability for each point 
        loss = modelCriterion(output, occupancies)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset), 100. * batch_idx / len(train_loader),
                loss.item()))
        if batch_idx % 100 == 0:
            print("Saving to model1.pth")
            torch.save(model.state_dict(), "model1.pth")

# %%
def validation(model, val_loader):
    model.eval()
    modelCriterion = nn.BCELoss()
    validation_loss = 0
    correct = 0
    for batch_idx, data in enumerate(val_loader):
        (images, pts, occupancies) = data
        images = images.view(batch_size*K,3,137,137).cuda() #make robust
        pts = pts.view(batch_size*K, 3,1).cuda()
        occupancies = occupancies.view(batch_size*K,1).cuda()
        output = model(pts, images)
        loss = modelCriterion(output, occupancies)
        validation_loss += loss.item()
        threshold = 0.2
        roundedOut = [1 if out > threshold else 0 for out in output.view(-1)]
        roundedOut = torch.tensor(roundedOut).cuda()
        correctNow = roundedOut.eq(occupancies.view(-1)).sum()
        correct += correctNow
        validation_loss /= len(val_loader.dataset)
        print('Validation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        validation_loss, correctNow, len(pts), 100. * correctNow / len(pts)))

# %%
#choose a category and load all of the available data:
import random
topdir = "/home/andrea/Documents/GradSchool/OccupancyNetworks/occupancy_networks"
imageFiles = ["000.jpg","001.jpg", "002.jpg","003.jpg", "004.jpg", "005.jpg", "006.jpg", "007.jpg", "008.jpg",
             "009.jpg", "010.jpg", "011.jpg", "012.jpg", "013.jpg", "014.jpg", "015.jpg", "016.jpg", "017.jpg",
             "018.jpg", "019.jpg", "020.jpg", "023.jpg"]

#One DataSetClass per subdirectory in a category, will return "K" point samples and a single image randomly
#drawn from the 23 available
class DataSetClass(torch.utils.data.Dataset):
    def __init__(self, d):
        self.dir = d
        with numpy.load(f"{d}/points.npz") as data:
            self.pts = torch.tensor(data["points"], dtype=torch.float)
            self.occupancies = torch.tensor(numpy.unpackbits(data["occupancies"])[:self.pts.size()[0]], dtype=torch.float)
        self.K = K #TODO how many sample points should come in? 
        self.length = int(self.occupancies.size()[0]/self.K)
    def __len__(self):
        return self.length
    
    def __getitem__(self,idx):
        #pick an image randomly to be used an observation for this set of "K sample points"
        imageFile = imageFiles[random.randint(0, len(imageFiles)-1)]
        with Image.open(f"{self.dir}/img_choy2016/{imageFile}") as image:
                image = numpy.array(image)
                image = torch.tensor(image,dtype=torch.float)
                #if the image is grey scale, stack 3 to conform dimensions
                if len(image.size()) < 3:
                    image = torch.stack([image, image, image])
                else:
                    image = image.permute(2,0,1)
        #Stack identical copies of the image so we have one for each input point
        #Maybe there is a better way
        image = torch.stack([image for _ in range(self.K)])
        #sampling in order is fine? 
        return image, self.pts[idx*self.K:(idx*self.K+self.K)], self.occupancies[idx*self.K:(idx*self.K+self.K)]

       
#catalogue all of the directories with the chosen category
trainingDirs = []
tablesDirectory=f"{topdir}/data/ShapeNet/02828884"
with io.open(f"{tablesDirectory}/train.lst") as trainlist:
    for traindir in trainlist.readlines():
        trainingDirs.append(f"{tablesDirectory}/{traindir.strip()}")
dataSets = []
for tdir in trainingDirs:
    dataSets.append(DataSetClass(tdir))
data = torch.utils.data.ConcatDataset(dataSets)
train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
#Get the validation data
valDirs = []
with io.open(f"{tablesDirectory}/val.lst") as vallist:
    for valdir in vallist.readlines():
        valDirs.append(f"{tablesDirectory}/{valdir.strip()}")
dataSets = []
for vdir in valDirs:
    dataSets.append(DataSetClass(vdir))
val_data = torch.utils.data.ConcatDataset(dataSets)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True)

# %%
### model = OccupancyModel().cuda()
optimizer = optim.Adam(model.parameters(), lr = 0.001)

for epoch in range(1):
    train(epoch,model,train_loader,optimizer)
    validation(model, val_loader)

# %%
torch.save(model.state_dict(), "model1.pth")

# %%
#TODO - switch to cabinet- we need a cube like object for more 1s
#TODO switch in BCE with Logits for loss, take out sigmoid in forward
#To take sigmoid at the output to get the probability 
#Seems like increasing batchsize to 20 and shuffle = True keep enough 1 occupancies in the game?

# %%
model = OccupancyModel()
model.load_state_dict(torch.load("model1.pth",map_location=device))
model.cuda()
model.eval()
# Out:
# OccupancyModel(
#   (blocks): Sequential(
#     (0): Block(
#       (fc1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (fc2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (gammaLayer1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (gammaLayer2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (betaLayer1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (betaLayer2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#     )
#     (1): Block(
#       (fc1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (fc2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (gammaLayer1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (gammaLayer2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (betaLayer1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (betaLayer2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#     )
#     (2): Block(
#       (fc1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (fc2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (gammaLayer1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (gammaLayer2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (betaLayer1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (betaLayer2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#     )
#     (3): Block(
#       (fc1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (fc2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (gammaLayer1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (gammaLayer2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (betaLayer1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (betaLayer2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#     )
#     (4): Block(
#       (fc1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (fc2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       (gammaLayer1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (gammaLayer2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (betaLayer1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#       (betaLayer2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (encoderModel): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=1000, bias=True)
#   )
#   (fc_enc): Linear(in_features=1000, out_features=256, bias=True)
#   (gammaLayer): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#   (betaLayer): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#   (cbn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (fc1): Conv1d(3, 256, kernel_size=(1,), stride=(1,))
#   (fc2): Conv1d(256, 1, kernel_size=(1,), stride=(1,))
# )

# %%
validation(model, val_loader)
# Out:
# Validation set: Average loss: 0.0000, Accuracy: 191/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 388/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 585/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 783/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 979/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 1170/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 1363/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 1559/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 1753/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 1950/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 2145/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 2338/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 2532/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 2728/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 2922/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 3118/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 3314/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 3509/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 3704/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 3898/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 4091/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 4289/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 4484/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 4680/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 4877/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 5076/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 5273/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 5463/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 5658/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 5857/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 6053/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 6249/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 6443/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 6638/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 6836/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 7032/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 7228/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 7425/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 7621/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 7818/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 8013/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 8206/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 8403/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 8599/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 8797/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 8991/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 9189/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 9382/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 9580/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 9776/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 9970/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 10167/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 10367/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 10559/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 10752/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 10947/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 11144/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 11339/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 11534/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 11729/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 11920/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 12116/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 12312/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 12507/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 12704/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 12898/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 13092/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 13291/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 13487/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 13682/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 13879/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 14072/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 14267/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 14462/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 14655/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 14852/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 15048/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 15243/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 15442/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 15631/200 (94%)
#
# Validation set: Average loss: 0.0000, Accuracy: 15826/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 16022/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 16219/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 16413/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 16607/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 16802/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 16996/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 17191/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 17388/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 17581/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 17777/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 17975/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 18171/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 18367/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 18562/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 18755/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 18951/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 19145/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 19340/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 19532/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 19723/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 19915/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 20110/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 20306/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 20504/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 20695/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 20893/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 21085/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 21279/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 21472/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 21666/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 21862/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 22052/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 22249/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 22444/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 22638/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 22836/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 23034/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 23229/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 23425/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 23622/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 23819/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 24015/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 24214/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 24409/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 24604/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 24796/200 (96%)
# Validation set: Average loss: 0.0000, Accuracy: 24989/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 25179/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 25376/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 25574/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 25769/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 25965/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 26161/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 26357/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 26554/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 26749/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 26946/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 27144/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 27341/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 27534/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 27730/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 27925/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 28116/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 28316/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 28511/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 28708/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 28906/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 29102/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 29297/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 29493/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 29689/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 29883/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 30078/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 30274/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 30471/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 30666/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 30858/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 31056/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 31254/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 31451/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 31643/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 31839/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 32033/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 32226/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 32421/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 32617/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 32814/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 33007/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 33200/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 33394/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 33591/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 33787/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 33982/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 34174/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 34367/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 34567/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 34764/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 34961/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 35157/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 35352/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 35548/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 35745/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 35938/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 36131/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 36327/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 36523/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 36717/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 36910/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 37107/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 37302/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 37498/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 37689/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 37886/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 38082/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 38278/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 38475/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 38675/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 38872/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 39067/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 39259/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 39455/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 39650/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 39844/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 40041/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 40235/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 40426/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 40622/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 40817/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 41016/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 41214/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 41410/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 41607/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 41804/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 42003/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 42201/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 42396/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 42590/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 42778/200 (94%)
#
# Validation set: Average loss: 0.0000, Accuracy: 42977/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 43171/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 43362/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 43560/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 43753/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 43949/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 44145/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 44340/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 44534/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 44731/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 44928/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 45124/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 45321/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 45517/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 45714/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 45910/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 46103/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 46299/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 46496/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 46692/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 46888/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 47080/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 47275/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 47470/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 47666/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 47860/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 48055/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 48250/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 48442/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 48637/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 48833/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 49026/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 49222/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 49419/200 (98%)
# Validation set: Average loss: 0.0000, Accuracy: 49611/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 49806/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 50001/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 50194/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 50389/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 50584/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 50781/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 50970/200 (94%)
#
# Validation set: Average loss: 0.0000, Accuracy: 51168/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 51365/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 51562/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 51753/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 51948/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 52140/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 52336/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 52532/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 52728/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 52925/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 53123/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 53316/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 53510/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 53707/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 53902/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 54099/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 54292/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 54489/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 54684/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 54879/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 55076/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 55274/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 55472/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 55668/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 55860/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 56055/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 56248/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 56441/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 56639/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 56834/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 57027/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 57227/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 57421/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 57616/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 57811/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 58007/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 58201/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 58393/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 58586/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 58781/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 58976/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 59171/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 59368/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 59562/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 59760/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 59955/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 60150/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 60344/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 60537/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 60731/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 60924/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 61121/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 61312/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 61501/200 (94%)
#
# Validation set: Average loss: 0.0000, Accuracy: 61699/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 61893/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 62086/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 62276/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 62473/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 62666/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 62864/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 63061/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 63259/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 63454/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 63649/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 63842/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 64037/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 64233/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 64427/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 64620/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 64819/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 65013/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 65210/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 65408/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 65607/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 65802/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 65998/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 66193/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 66387/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 66582/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 66780/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 66977/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 67174/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 67365/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 67559/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 67753/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 67944/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 68139/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 68334/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 68527/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 68723/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 68921/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 69116/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 69314/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 69504/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 69699/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 69897/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 70092/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 70290/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 70487/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 70682/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 70873/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 71068/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 71261/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 71459/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 71655/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 71850/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 72048/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 72245/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 72440/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 72636/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 72833/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 73031/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 73221/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 73419/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 73614/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 73810/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 74003/200 (96%)
# Validation set: Average loss: 0.0000, Accuracy: 74200/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 74394/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 74588/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 74778/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 74972/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 75165/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 75361/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 75557/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 75757/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 75956/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 76151/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 76347/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 76540/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 76730/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 76928/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 77122/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 77316/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 77513/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 77706/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 77900/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 78100/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 78291/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 78487/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 78681/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 78877/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 79075/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 79271/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 79467/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 79662/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 79856/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 80050/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 80245/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 80443/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 80642/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 80832/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 81027/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 81226/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 81423/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 81617/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 81813/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 82007/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 82202/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 82399/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 82591/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 82787/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 82984/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 83178/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 83371/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 83561/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 83756/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 83950/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 84146/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 84340/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 84538/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 84736/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 84932/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 85126/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 85320/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 85514/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 85709/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 85904/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 86097/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 86290/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 86482/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 86674/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 86872/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 87070/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 87265/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 87459/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 87650/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 87846/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 88042/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 88237/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 88423/200 (93%)
#
# Validation set: Average loss: 0.0000, Accuracy: 88619/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 88811/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 89008/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 89201/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 89395/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 89590/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 89784/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 89980/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 90173/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 90368/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 90566/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 90762/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 90957/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 91154/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 91351/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 91551/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 91741/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 91939/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 92138/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 92332/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 92527/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 92725/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 92918/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 93110/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 93300/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 93496/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 93692/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 93884/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 94080/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 94276/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 94470/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 94666/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 94863/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 95061/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 95253/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 95440/200 (94%)
#
# Validation set: Average loss: 0.0000, Accuracy: 95635/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 95820/200 (92%)
#
# Validation set: Average loss: 0.0000, Accuracy: 96017/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 96213/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 96410/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 96603/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 96800/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 96994/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 97193/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 97390/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 97589/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 97788/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 97985/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 98183/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 98381/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 98575/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 98772/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 98964/200 (96%)
# Validation set: Average loss: 0.0000, Accuracy: 99157/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 99350/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 99547/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 99741/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 99938/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 100136/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 100326/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 100522/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 100714/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 100910/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 101106/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 101303/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 101502/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 101696/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 101893/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 102087/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 102285/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 102482/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 102672/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 102872/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 103069/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 103266/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 103462/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 103653/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 103853/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 104051/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 104245/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 104442/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 104636/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 104835/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 105031/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 105227/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 105425/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 105624/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 105819/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 106016/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 106210/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 106403/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 106600/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 106799/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 106993/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 107187/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 107382/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 107577/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 107773/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 107969/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 108166/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 108362/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 108557/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 108756/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 108949/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 109144/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 109341/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 109538/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 109738/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 109934/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 110131/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 110326/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 110519/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 110716/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 110907/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 111102/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 111296/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 111490/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 111683/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 111880/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 112077/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 112274/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 112469/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 112665/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 112862/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 113056/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 113253/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 113453/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 113650/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 113846/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 114039/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 114238/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 114433/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 114628/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 114824/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 115020/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 115217/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 115412/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 115609/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 115801/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 115994/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 116189/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 116385/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 116577/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 116772/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 116967/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 117165/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 117361/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 117559/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 117755/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 117948/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 118143/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 118339/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 118535/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 118729/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 118924/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 119117/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 119315/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 119511/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 119706/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 119897/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 120092/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 120290/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 120488/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 120683/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 120881/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 121075/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 121269/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 121466/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 121662/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 121856/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 122051/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 122243/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 122434/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 122630/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 122829/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 123026/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 123223/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 123417/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 123610/200 (96%)
# Validation set: Average loss: 0.0000, Accuracy: 123806/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 123999/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 124197/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 124391/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 124584/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 124779/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 124970/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 125164/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 125361/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 125553/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 125748/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 125943/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 126138/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 126333/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 126530/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 126724/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 126920/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 127115/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 127308/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 127502/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 127697/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 127895/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 128090/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 128287/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 128482/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 128677/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 128874/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 129064/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 129260/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 129452/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 129647/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 129840/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 130033/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 130228/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 130420/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 130614/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 130810/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 131006/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 131202/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 131400/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 131598/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 131794/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 131989/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 132184/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 132376/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 132568/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 132764/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 132961/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 133159/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 133352/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 133549/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 133744/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 133941/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 134132/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 134328/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 134524/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 134719/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 134909/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 135103/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 135302/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 135500/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 135691/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 135884/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 136080/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 136276/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 136468/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 136666/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 136864/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 137059/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 137254/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 137448/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 137635/200 (94%)
#
# Validation set: Average loss: 0.0000, Accuracy: 137831/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 138028/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 138223/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 138419/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 138619/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 138810/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 139003/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 139198/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 139396/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 139593/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 139791/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 139982/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 140177/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 140375/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 140573/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 140772/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 140967/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 141165/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 141361/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 141556/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 141748/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 141939/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 142136/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 142335/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 142529/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 142722/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 142919/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 143110/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 143301/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 143498/200 (98%)
#
# ...
#
# Validation set: Average loss: 0.0000, Accuracy: 154395/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 154591/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 154786/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 154982/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 155181/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 155378/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 155572/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 155762/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 155959/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 156156/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 156349/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 156548/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 156746/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 156941/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 157137/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 157335/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 157525/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 157718/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 157914/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 158111/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 158307/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 158500/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 158696/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 158889/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 159087/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 159281/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 159477/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 159673/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 159870/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 160068/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 160263/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 160460/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 160652/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 160847/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 161042/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 161237/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 161431/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 161623/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 161820/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 162017/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 162214/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 162411/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 162606/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 162796/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 162992/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 163188/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 163379/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 163572/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 163771/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 163965/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 164158/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 164354/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 164551/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 164744/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 164940/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 165136/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 165332/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 165530/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 165725/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 165917/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 166115/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 166310/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 166507/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 166705/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 166903/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 167093/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 167288/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 167485/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 167679/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 167873/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 168069/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 168267/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 168462/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 168655/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 168853/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 169048/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 169242/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 169437/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 169630/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 169825/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 170016/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 170209/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 170405/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 170599/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 170793/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 170992/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 171188/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 171385/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 171585/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 171776/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 171965/200 (94%)
#
# Validation set: Average loss: 0.0000, Accuracy: 172156/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 172348/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 172542/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 172732/200 (95%)
# Validation set: Average loss: 0.0000, Accuracy: 172926/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 173120/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 173319/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 173515/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 173711/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 173905/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 174099/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 174298/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 174495/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 174689/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 174885/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 175083/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 175277/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 175475/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 175672/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 175864/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 176057/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 176255/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 176453/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 176649/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 176847/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 177043/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 177238/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 177437/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 177633/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 177830/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 178024/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 178220/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 178416/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 178614/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 178805/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 179000/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 179199/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 179399/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 179591/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 179789/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 179984/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 180177/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 180369/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 180562/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 180756/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 180949/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 181143/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 181339/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 181536/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 181735/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 181933/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 182127/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 182322/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 182518/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 182716/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 182912/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 183110/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 183306/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 183502/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 183697/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 183890/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 184085/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 184277/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 184473/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 184667/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 184865/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 185062/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 185258/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 185453/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 185647/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 185847/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 186042/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 186239/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 186432/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 186626/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 186822/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 187019/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 187214/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 187407/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 187604/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 187799/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 187992/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 188190/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 188387/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 188583/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 188782/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 188976/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 189171/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 189368/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 189565/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 189760/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 189957/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 190150/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 190344/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 190539/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 190735/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 190932/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 191122/200 (95%)
#
# Validation set: Average loss: 0.0000, Accuracy: 191319/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 191513/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 191706/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 191903/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 192099/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 192291/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 192485/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 192683/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 192878/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 193075/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 193269/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 193461/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 193656/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 193850/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 194045/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 194241/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 194437/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 194635/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 194827/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 195020/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 195217/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 195413/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 195610/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 195808/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 196007/200 (100%)
#
# Validation set: Average loss: 0.0000, Accuracy: 196202/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 196394/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 196587/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 196780/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 196977/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 197172/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 197361/200 (94%)
# Validation set: Average loss: 0.0000, Accuracy: 197557/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 197752/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 197945/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 198142/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 198340/200 (99%)
#
# Validation set: Average loss: 0.0000, Accuracy: 198534/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 198728/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 198924/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 199121/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 199315/200 (97%)
#
# Validation set: Average loss: 0.0000, Accuracy: 199512/200 (98%)
#
# Validation set: Average loss: 0.0000, Accuracy: 199704/200 (96%)
#
# Validation set: Average loss: 0.0000, Accuracy: 199899/200 (98%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ac98fbb2221e> in <module>
# ----> 1 validation(model, val_loader)
#
# <ipython-input-6-820dec6a1de4> in validation(model, val_loader)
#      11         output = model(pts, images)
#      12         loss = modelCriterion(output, occupancies)
# ---> 13         validation_loss += loss.item()
#      14         threshold = 0.2
#      15         outout = output.view(-1)
#
# KeyboardInterrupt:
